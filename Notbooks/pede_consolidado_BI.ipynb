# %%
import pandas as pd

# %%
caminho = 'BASE DE DADOS PEDE 2024 - DATATHON - GERAL.xlsx'

# %%
df_22 = pd.read_excel(caminho, sheet_name='PEDE2022')
df_23 = pd.read_excel(caminho, sheet_name='PEDE2023')
df_24 = pd.read_excel(caminho, sheet_name='PEDE2024')

# %%
df_22['ano'] = 2022
df_23['ano'] = 2023
df_24['ano'] = 2024

# %%
df = pd.concat([df_22, df_23, df_24], ignore_index=True)

# %%
colunas_base = ['Defasagem', 'Fase', 'Gênero', 'IAA', 'IAN', 'IDA', 'IEG', 'INDE', 'IPP', 'IPS', 'IPV', 'Nome', 'Pedra', 'RA', 'Ano nasc', 'Ano ingresso', 'Fase ideal', 'ano']

# %%
df = df[colunas_base]
df.head()
# Out:
#    Defasagem Fase  Gênero  IAA   IAN  IDA  IEG   INDE    IPP  IPS    IPV  \
# 0         -1    7  Menina  8.3   5.0  4.0  4.1  5.783  8.174  5.6  7.278
# 1          0    7  Menina  8.8  10.0  6.8  5.2  7.055  7.894  6.3  6.778
# 2          0    7  Menina  0.0  10.0  5.6  7.9  6.591  8.198  5.6  7.556
# 3          0    7  Menino  8.8  10.0  5.0  4.5  5.951  5.554  5.6  5.278
# 4          0    7  Menina  7.9  10.0  5.2  8.6  7.427  8.392  5.6  7.389
#
#       Nome     Pedra    RA Ano nasc  Ano ingresso               Fase ideal  \
# 0  Aluno-1   Quartzo  RA-1     2003          2016  Fase 8 (Universitários)
# 1  Aluno-2  Ametista  RA-2     2005          2017           Fase 7 (3º EM)
# 2  Aluno-3     Ágata  RA-3     2005          2016           Fase 7 (3º EM)
# 3  Aluno-4   Quartzo  RA-4     2005          2017           Fase 7 (3º EM)
# 4  Aluno-5  Ametista  RA-5     2005          2016           Fase 7 (3º EM)
#
#     ano
# 0  2022
# 1  2022
# 2  2022
# 3  2022
# 4  2022

# %%
# 4. Exportamos o CSV atualizado, agora com os nomes!
df.to_csv('PEDE_CONSOLIDADO.csv', index=False)
